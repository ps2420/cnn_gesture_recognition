# %% [markdown]
# # Gesture Recognition
#
# ## Problem statement
# A home electronics company which manufactures state of the art smart televisions, wants to develop a cool feature in the smart-TV. That can recognise five different gestures performed by the user which will help users control the TV without using a remote. The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# Thumbs up: Increase the volume
# Thumbs down: Decrease the volume
# Left swipe: 'Jump' backwards 10 seconds
# Right swipe: 'Jump' forward 10 seconds
# Stop: Pause the movie

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os

# %%
#!pip install scipy==1.1.0

# %%
import warnings
warnings.filterwarnings('ignore')

import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %% [markdown]
# np.random.seed(30)
# import random as rn
# rn.seed(30)
# from keras import backend as K
# import tensorflow as tf
# #tf.set_random_seed(30)
# tf.random.set_seed(30)

# %%
data_dir = '/home/datasets/Project_data'

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open(data_dir + '/train.csv').readlines())
val_doc = np.random.permutation(open(data_dir + '/val.csv').readlines())
batch_size = 40 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
x = 30 # No. of frames images
#y = 120 # Width of the image
#z = 120 # height

# parameterize the width and height to test with different sizes
def generator(source_path, folder_list, batch_size, width=120, height=120):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [x for x in range(0,x)] #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size# calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size, x, width, height, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    resized_image = resize(image,(width, height)) ##default resample=1 or 'P' which indicates PIL.Image.NEAREST
                    resized_image = resized_image/255
                    
                
                    batch_data[folder,idx,:,:,0] = (resized_image[:,:,0])#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (resized_image[:,:,1])#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (resized_image[:,:,2])#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size * num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x, width, height, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    resized_image = resize(image,(width, height)) ##default resample=1 or 'P' which indicates PIL.Image.NEAREST
                    resized_image = resized_image/255 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (resized_image[:,:,0])
                    batch_data[folder,idx,:,:,1] = (resized_image[:,:,1])
                    batch_data[folder,idx,:,:,2] = (resized_image[:,:,2])
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = data_dir + '/train'
val_path = data_dir + '/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 15

# %% [markdown]
# #### Import libraries and define model-checkpoint

# %%
# Import all the necessary libraries to train model
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.layers.recurrent import LSTM
#from keras import optimizers #Code provided by upgrad does not work
from keras import optimizers

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
# Note change the parameter to False, else disk would run out of space.

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# #### Define model architectures to reuse later with different epoc, batch sizes and train model with different image sizes

# %%
class model_architecture:
    # initialize default parameter
    num_epochs = 25
    batch_size = 40
    image_width_height = 120
    
    #defining constructor  
    def __init__(self, num_epochs = 15, batch_size = 40, image_width_height = 120):  
        self.num_epochs = num_epochs  
        self.batch_size = batch_size 
        self.image_width_height = image_width_height
        
    def define_conv3d_architecture_1(self):
        model_arch_1 = Sequential()       
        model_arch_1.add(Conv3D(8,kernel_size=(3,3,3),input_shape=(30, self.image_width_height, self.image_width_height, 3),padding='same'))
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(Activation('relu'))

        model_arch_1.add(Conv3D(16, (3, 3, 3), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(32, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(64, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(128, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))      

        # Flatten layer 
        model_arch_1.add(Flatten())
        model_arch_1.add(Dense(1000, activation='relu'))
        model_arch_1.add(Dropout(0.5))

        model_arch_1.add(Dense(500, activation='relu'))
        model_arch_1.add(Dropout(0.5))

        #Softmax layer
        model_arch_1.add(Dense(5, activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.001) #write your optimizer
        model_arch_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        print (model_arch_1.summary())

        self.model_arch = model_arch_1
        
    # SGD optimizer with decay, momentum and nesterov    
    def define_conv3d_architecture_1_sgd_variant(self):
        model_arch_1 = Sequential()       
        model_arch_1.add(Conv3D(8,kernel_size=(3,3,3),input_shape=(30, self.image_width_height, self.image_width_height, 3),padding='same'))
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(Activation('relu'))

        model_arch_1.add(Conv3D(16, (3, 3, 3), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(32, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(64, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(128, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))      

        # Flatten layer 
        model_arch_1.add(Flatten())
        model_arch_1.add(Dense(1000, activation='relu'))
        model_arch_1.add(Dropout(0.5))

        model_arch_1.add(Dense(500, activation='relu'))
        model_arch_1.add(Dropout(0.5))

        #Softmax layer
        model_arch_1.add(Dense(5, activation='softmax'))

        optimiser = tf.keras.optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True) #write your optimizer
        model_arch_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        print (model_arch_1.summary())

        self.model_arch = model_arch_1    

    
    # different variant of architecture 1, with dropouts at more dense layer   
    def define_conv3d_architecture_2(self):
        model_arch_2 = Sequential()       
        model_arch_2.add(Conv3D(8,kernel_size=(3,3,3),input_shape=(30, self.image_width_height, self.image_width_height, 3),padding='same'))
        model_arch_2.add(BatchNormalization())
        model_arch_2.add(Activation('relu'))

        model_arch_2.add(Conv3D(16, (3, 3, 3), activation='relu', padding='same')) 
        model_arch_2.add(BatchNormalization())
        model_arch_2.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_2.add(Conv3D(32, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_2.add(BatchNormalization())
        model_arch_2.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model_arch_2.add(Dropout(0.25))

        model_arch_2.add(Conv3D(64, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_2.add(BatchNormalization())
        model_arch_2.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model_arch_2.add(Dropout(0.25))

        model_arch_2.add(Conv3D(128, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_2.add(BatchNormalization())
        model_arch_2.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model_arch_2.add(Dropout(0.25))

        # Flatten layer 
        model_arch_2.add(Flatten())
        model_arch_2.add(Dense(1000, activation='relu'))
        model_arch_2.add(Dropout(0.5))

        model_arch_2.add(Dense(500, activation='relu'))
        model_arch_2.add(Dropout(0.5))

        #Softmax layer
        model_arch_2.add(Dense(5, activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.001) #write your optimizer
        model_arch_2.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        print (model_arch_2.summary())

        self.model_arch = model_arch_2
    
    #architecture with different layer and drop-out at dense layer with 0.5 & 0.25
    def define_conv3d_architecture_3(self):
        model_arch_3 = Sequential()       
        model_arch_3.add(Conv3D(16,kernel_size=(3,3,3),input_shape=(30, self.image_width_height, self.image_width_height, 3), activation='relu', padding='same'))
        model_arch_3.add(BatchNormalization())
        model_arch_3.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_3.add(Conv3D(32, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_3.add(BatchNormalization())
        model_arch_3.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_3.add(Conv3D(64, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_3.add(BatchNormalization())
        model_arch_3.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model_arch_3.add(Conv3D(128, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_3.add(BatchNormalization())
        model_arch_3.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model_arch_3.add(Dropout(0.25))

        # Flatten layer 
        model_arch_3.add(Flatten())
        model_arch_3.add(Dense(1000, activation='relu'))
        model_arch_3.add(Dropout(0.5))

        model_arch_3.add(Dense(500, activation='relu'))
        model_arch_3.add(Dropout(0.25))

        #Softmax layer
        model_arch_3.add(Dense(5, activation='softmax'))
        
        optimiser = tf.keras.optimizers.Adam(lr=0.001) #write your optimizer
        
        model_arch_3.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        print (model_arch_3.summary())

        self.model_arch = model_arch_3

    # Define LSTM architecture
    def define_rnn_lstm_architecture_1(self):
        model_rnn_lstm = Sequential()   
        model_rnn_lstm.add(TimeDistributed(Conv2D(8, (3, 3), padding='same', activation='relu'), input_shape=(30, self.image_width_height, self.image_width_height, 3)))
        model_rnn_lstm.add(TimeDistributed(BatchNormalization()))
        model_rnn_lstm.add(TimeDistributed(MaxPooling2D((2, 2))))

        model_rnn_lstm.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu')))
        model_rnn_lstm.add(TimeDistributed(BatchNormalization()))
        model_rnn_lstm.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model_rnn_lstm.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model_rnn_lstm.add(TimeDistributed(BatchNormalization()))
        model_rnn_lstm.add(TimeDistributed(MaxPooling2D((2, 2))))

        model_rnn_lstm.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model_rnn_lstm.add(TimeDistributed(BatchNormalization()))
        model_rnn_lstm.add(TimeDistributed(MaxPooling2D((2, 2))))

        model_rnn_lstm.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model_rnn_lstm.add(TimeDistributed(BatchNormalization()))
        model_rnn_lstm.add(TimeDistributed(MaxPooling2D((2, 2))))

        # Flatten layer 
        model_rnn_lstm.add(TimeDistributed(Flatten()))
        model_rnn_lstm.add(LSTM(256))
        model_rnn_lstm.add(Dropout(0.25))

        # Dense layer 
        model_rnn_lstm.add(Dense(128,activation='relu'))
        model_rnn_lstm.add(Dropout(0.25))

        # Softmax layer
        model_rnn_lstm.add(Dense(5, activation='softmax'))

        # Adam optimiser
        optimiser = tf.keras.optimizers.Adam(lr=0.001) #write your optimizer
        model_rnn_lstm.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        print (model_rnn_lstm.summary())
        
        self.model_arch = model_rnn_lstm
    
    
    #Define gru architecture, to be compared with LSTM
    def define_rnn_gru_architecture_1(self):
        model_rnn_gru = Sequential()   
        model_rnn_gru.add(TimeDistributed(Conv2D(8, (3, 3), padding='same', activation='relu'), input_shape=(30, self.image_width_height, self.image_width_height, 3)))
        model_rnn_gru.add(TimeDistributed(BatchNormalization()))
        model_rnn_gru.add(TimeDistributed(MaxPooling2D((2, 2))))

        model_rnn_gru.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu')))
        model_rnn_gru.add(TimeDistributed(BatchNormalization()))
        model_rnn_gru.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model_rnn_gru.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model_rnn_gru.add(TimeDistributed(BatchNormalization()))
        model_rnn_gru.add(TimeDistributed(MaxPooling2D((2, 2))))

        model_rnn_gru.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model_rnn_gru.add(TimeDistributed(BatchNormalization()))
        model_rnn_gru.add(TimeDistributed(MaxPooling2D((2, 2))))

        model_rnn_gru.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model_rnn_gru.add(TimeDistributed(BatchNormalization()))
        model_rnn_gru.add(TimeDistributed(MaxPooling2D((2, 2))))

        # Flatten layer 
        model_rnn_gru.add(TimeDistributed(Flatten()))
        model_rnn_gru.add(GRU(256))
        model_rnn_gru.add(Dropout(0.25))

        # Dense layer 
        model_rnn_gru.add(Dense(128,activation='relu'))
        model_rnn_gru.add(Dropout(0.25))

        # Softmax layer
        model_rnn_gru.add(Dense(5, activation='softmax'))

        # Adam optimiser
        optimiser = tf.keras.optimizers.Adam(lr=0.001) #write your optimizer
        model_rnn_gru.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        print (model_rnn_gru.summary())
        
        self.model_arch = model_rnn_gru
    
    
    def cal_validation_steps_per_epoch(self):
        if (num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (num_train_sequences//self.batch_size) + 1

        if (num_val_sequences%batch_size) == 0:
            validation_steps = int(num_val_sequences/self.batch_size)
        else:
            validation_steps = (num_val_sequences//self.batch_size) + 1

        return steps_per_epoch, validation_steps

    def plot(self, history):
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
        axes[0].plot(history.history['loss'])   
        axes[0].plot(history.history['val_loss'])
        axes[0].grid()
        axes[0].legend(['loss','val_loss'])
        axes[1].plot(history.history['categorical_accuracy'])   
        axes[1].plot(history.history['val_categorical_accuracy'])
        axes[1].grid()
        axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    
    def execute(self):
        # Now that you have defined the model in define_conv3d_architecture_1, the next step is to `compile` the model. 
        # When you print the `summary` of the model, you'll see the total number of parameters you have to train.
        train_generator = generator(train_path, train_doc, self.batch_size, self.image_width_height, self.image_width_height)
        val_generator = generator(val_path, val_doc, self.batch_size, self.image_width_height, self.image_width_height)

        #The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
        steps_per_epoch, validation_steps = self.cal_validation_steps_per_epoch()

        history = self.model_arch.fit_generator(train_generator, steps_per_epoch = steps_per_epoch, epochs = self.num_epochs, verbose=1, 
                        callbacks = callbacks_list, validation_data = val_generator, 
                        validation_steps = validation_steps, class_weight=None, workers=1, initial_epoch=0)
        self.plot(history)
        
        return history

# %% [markdown]
# # Train Model with different epochs: 15, 25 (image size:30) and (batch size:30, epochs: 25) to compare the model performance

# %% [markdown]
# #### Model-1 input summary (Conv3d architecture)
# #### Initial run with less number of epochs to see our architecture fits.
# - input image size(120x120)
# - epochs: 15
# - batch size: 40
#
# ### Expected output: Architecture should overfit with small number epochs

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_1 = model_architecture(15, 40, 120)
model_1.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_1.execute()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_15 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  batch_normalization_35 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  activation_3 (Activation)   (None, 30, 120, 120, 8)   0
#
#  conv3d_16 (Conv3D)          (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_36 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_17 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_37 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_18 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_38 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_19 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_39 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_7 (Flatten)         (None, 6272)              0
#
#  dense_18 (Dense)            (None, 1000)              6273000
#
#  dropout_14 (Dropout)        (None, 1000)              0
#
#  dense_19 (Dense)            (None, 500)               500500
#
#  dropout_15 (Dropout)        (None, 500)               0
#
#  dense_20 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/15
# 17/17 [==============================] - ETA: 0s - loss: 6.9565 - categorical_accuracy: 0.3424Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.33532
# 17/17 [==============================] - 82s 5s/step - loss: 6.9565 - categorical_accuracy: 0.3424 - val_loss: 2.6823 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 2/15
# 17/17 [==============================] - ETA: 0s - loss: 2.0153 - categorical_accuracy: 0.4885
# Epoch 00002: val_loss did not improve from 0.33532
# 17/17 [==============================] - 48s 3s/step - loss: 2.0153 - categorical_accuracy: 0.4885 - val_loss: 2.0813 - val_categorical_accuracy: 0.1667 - lr: 0.0010
# Epoch 3/15
# 17/17 [==============================] - ETA: 0s - loss: 1.8115 - categorical_accuracy: 0.4714
# Epoch 00003: val_loss did not improve from 0.33532
# 17/17 [==============================] - 46s 3s/step - loss: 1.8115 - categorical_accuracy: 0.4714 - val_loss: 2.1509 - val_categorical_accuracy: 0.2333 - lr: 0.0010
# Epoch 4/15
# 17/17 [==============================] - ETA: 0s - loss: 1.2038 - categorical_accuracy: 0.6223
# Epoch 00004: val_loss did not improve from 0.33532
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] -
15
# 17/17 [==============================] - ETA: 0s - loss: 0.2870 - categorical_accuracy: 0.8789
# Epoch 00015: val_loss did not improve from 0.33532
# 17/17 [==============================] - 36s 2s/step - loss: 0.2870 - categorical_accuracy: 0.8789 - val_loss: 5.5734 - val_categorical_accuracy: 0.2833 - lr: 1.5625e-05

# %% [markdown]
# #### Model-1 output summary (num_epoch=15, batch_size=40)
# - Training accuracy: 87.89
# - Validation accuracy: 28.33
# - Validation loss: 5.5734
#
# ##### In initial run we see model overfits with less number of epochs. Validation loss did not improve and fairly averaged around 10. With less number of epochs (15) validation loss ends with 8.3430. Running the model with more number of epochs should be tried.

# %% [markdown]
# ### Model-2 input summary (Conv3d architecture) : Hyperparameter tuning (With more number of epochs)
# - input image size(120x120)
# - epochs: 25
# - batch size: 40
#
# ### Expected output: Compared to previous architecture, training/validation accuracy should improve and validation loss should go down

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_2 = model_architecture(25, 40, 120)
model_2.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_2.execute()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  batch_normalization_20 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  activation_4 (Activation)   (None, 30, 120, 120, 8)   0
#
#  conv3d_21 (Conv3D)          (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_21 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_22 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_17 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_23 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_23 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_18 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_24 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_24 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_12 (Dense)            (None, 1000)              6273000
#
#  dropout_8 (Dropout)         (None, 1000)              0
#
#  dense_13 (Dense)            (None, 500)               500500
#
#  dropout_9 (Dropout)         (None, 500)               0
#
#  dense_14 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/25
# 17/17 [==============================] - ETA: 0s - loss: 7.4892 - categorical_accuracy: 0.3092Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 1.05296
# 17/17 [==============================] - 109s 7s/step - loss: 7.4892 - categorical_accuracy: 0.3092 - val_loss: 2.1379 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 2/25
# 17/17 [==============================] - ETA: 0s - loss: 2.5008 - categorical_accuracy: 0.4808
# Epoch 00002: val_loss did not improve from 1.05296
# 17/17 [==============================] - 59s 4s/step - loss: 2.5008 - categorical_accuracy: 0.4808 - val_loss: 2.0435 - val_categorical_accuracy: 0.2167 - lr: 0.0010
# Epoch 3/25
# 17/17 [==============================] - ETA: 0s - loss: 1.3609 - categorical_accuracy: 0.5586
# Epoch 00003: val_loss did not improve from 1.05296
# 17/17 [==============================] - 60s 4s/step - loss: 1.3609 - categorical_accuracy: 0.5586 - val_loss: 6.1559 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 4/25
# 17/17 [==============================] - ETA: 0s - loss: 1.2974 - categorical_accuracy: 0.6316
# Epoch 00004: val_loss did not improve from 1.05296
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] - 59s 4s/step - loss: 1.2974 - categorical_accuracy: 0.6316 - val_loss: 6.5454 - val_categorical_accuracy: 0.2333 - lr: 0.0010
# Epoch 5/25
# 17/17 [==============================] - ETA: 0s - loss: 1.3646 - categorical_accuracy: 0.6006
# Epoch 00005: val_loss did not improve from 1.05296
# 17/17 [==============================] - 54s 3s/step - loss: 1.3646 - categorical_accuracy: 0.6006 - val_loss: 6.3743 - val_categorical_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 6/25
# 17/17 [==============================] - ETA: 0s - loss: 0.8290 - categorical_accuracy: 0.7163
# Epoch 00006: val_loss did not improve from 1.05296
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 [==============================] - 50s 3s/step - loss: 0.8290 - categorical_accuracy: 0.7163 - val_loss: 9.1646 - val_categorical_accuracy: 0.1167 - lr: 5.0000e-04
# Epoch 7/25
# 17/17 [==============================] - ETA: 0s - loss: 0.
25
# 17/17 [==============================] - ETA: 0s - loss: 0.3074 - categorical_accuracy: 0.8962
# Epoch 00018: val_loss did not improve from 1.05296
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 17/17 [==============================] - 42s 3s/step - loss: 0.3074 - categorical_accuracy: 0.8962 - val_loss: 5.0978 - val_categorical_accuracy: 0.3333 - lr: 7.8125e-06
# Epoch 19/25
# 17/17 [==============================] - ETA: 0s - loss: 0.3313 - categorical_accuracy: 0.8616
# Epoch 00019: val_loss did not improve from 1.05296
# 17/17 [==============================] - 44s 3s/step - loss: 0.3313 - categorical_accuracy: 0.8616 - val_loss: 4.9027 - val_categorical_accuracy: 0.2833 - lr: 3.9063e-06
# Epoch 20/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2878 - categorical_accuracy: 0.8997
# Epoch 00020: val_loss did not improve from 1.05296
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 17/17 [==============================] - 44s 3s/step - loss: 0.2878 - categorical_accuracy: 0.8997 - val_loss: 3.9757 - val_categorical_accuracy: 0.4000 - lr: 3.9063e-06
# Epoch 21/25
# 17/17 [==============================] - ETA: 0s - loss: 0.3032 - categorical_accuracy: 0.8962
# Epoch 00021: val_loss did not improve from 1.05296
# 17/17 [==============================] - 37s 2s/step - loss: 0.3032 - categorical_accuracy: 0.8962 - val_loss: 3.5678 - val_categorical_accuracy: 0.3833 - lr: 1.9531e-06
# Epoch 22/25
# 17/17 [==============================] - ETA: 0s - loss: 0.3256 - categorical_accuracy: 0.9066
# Epoch 00022: val_loss did not improve from 1.05296
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 17/17 [==============================] - 38s 2s/step - loss: 0.3256 - categorical_accuracy: 0.9066 - val_loss: 3.7039 - val_categorical_accuracy: 0.3667 - lr: 1.9531e-06
# Epoch 23/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2323 - categorical_accuracy: 0.9204
# Epoch 00023: val_loss did not improve from 1.05296
# 17/17 [==============================] - 36s 2s/step - loss: 0.2323 - categorical_accuracy: 0.9204 - val_loss: 3.3438 - val_categorical_accuracy: 0.3500 - lr: 9.7656e-07
# Epoch 24/25
# 17/17 [==============================] - ETA: 0s - loss: 0.3063 - categorical_accuracy: 0.8858
# Epoch 00024: val_loss did not improve from 1.05296
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 17/17 [==============================] - 37s 2s/step - loss: 0.3063 - categorical_accuracy: 0.8858 - val_loss: 2.1900 - val_categorical_accuracy: 0.5333 - lr: 9.7656e-07
# Epoch 25/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2705 - categorical_accuracy: 0.8893
# Epoch 00025: val_loss did not improve from 1.05296
# 17/17 [==============================] - 37s 2s/step - loss: 0.2705 - categorical_accuracy: 0.8893 - val_loss: 2.3392 - val_categorical_accuracy: 0.5000 - lr: 4.8828e-07

# %% [markdown]
# #### Model-2 output summary (num_epoch=25, batch_size=40)
# - Training accuracy: 88.93
# - Validation accuracy: 50.00
# - Validation loss: 2.3392
#
# We can observe compared to previous model, after training for more number of epochs model validation accuracy, training accuracy and validation loss did improve.
#
# Before running for more number of epochs, we should try out with different batch sizes, and image resolution to see the validaton loss and accuracy.

# %% [markdown]
# ### Model-3 input summary (Conv3d architecture): (Hyperparameter tuning with reduced batch size of 30)
# - input image size(120x120)
# - epochs: 25
# - batch size: 30

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_3 = model_architecture(25, 30, 120)
model_3.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_3.execute()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_25 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  batch_normalization_25 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  activation_5 (Activation)   (None, 30, 120, 120, 8)   0
#
#  conv3d_26 (Conv3D)          (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_26 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_27 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_27 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_28 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_28 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_29 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_29 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_23 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#  dense_15 (Dense)            (None, 1000)              6273000
#
#  dropout_10 (Dropout)        (None, 1000)              0
#
#  dense_16 (Dense)            (None, 500)               500500
#
#  dropout_11 (Dropout)        (None, 500)               0
#
#  dense_17 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size =
25
# 23/23 [==============================] - ETA: 0s - loss: 0.7910 - categorical_accuracy: 0.7101
# Epoch 00024: val_loss did not improve from 1.05296
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 23/23 [==============================] - 14s 611ms/step - loss: 0.7910 - categorical_accuracy: 0.7101 - val_loss: 1.7519 - val_categorical_accuracy: 0.4500 - lr: 1.5625e-05
# Epoch 25/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9080 - categorical_accuracy: 0.6667
# Epoch 00025: val_loss did not improve from 1.05296
# 23/23 [==============================] - 13s 573ms/step - loss: 0.9080 - categorical_accuracy: 0.6667 - val_loss: 1.1260 - val_categorical_accuracy: 0.6750 - lr: 7.8125e-06

# %% [markdown]
# #### Model-3 output summary (batch size: 30, epochs:25)
# - Training accuracy: 66.67
# - Validation accuracy: 67.50
# - Validation loss : 1.126
#
# #### We can observe that training with batch size of 30 did improve the validation loss and validation accuracy, but training accuracy went down.
# #### Training the model with higher number of batches (40) did perform better as training accuracy fairly remains high and loss/accuracy has smooth curve compared to training with batch size. Training with 30 batch size, steep curve was spotted

# %% [markdown]
# ## With image size (120x120) when model was trained with different batch sizes and epochs, it was observed model performs better (with epoch: 25, batch size: 40) better

# %% [markdown]
# # Train model with batch size: (40&50), epoch: 25 and compare the output for Image size (150x150)

# %% [markdown]
# ### Model-4 input summary (Conv3d architecture): With image size 150x150
#
# - input image size(150x150)
# - epochs: 25
# - batch size: 40
#
# In this attempt, try to change the image width/height size and see how it performed compared to previous model in 25 nb of epocs

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_4 = model_architecture(25, 40, 150)
model_4.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_4.execute()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_30 (Conv3D)          (None, 30, 150, 150, 8)   656
#
#  batch_normalization_30 (Bat  (None, 30, 150, 150, 8)  32
#  chNormalization)
#
#  activation_6 (Activation)   (None, 30, 150, 150, 8)   0
#
#  conv3d_31 (Conv3D)          (None, 30, 150, 150, 16)  3472
#
#  batch_normalization_31 (Bat  (None, 30, 150, 150, 16)  64
#  chNormalization)
#
#  max_pooling3d_24 (MaxPoolin  (None, 15, 75, 75, 16)   0
#  g3D)
#
#  conv3d_32 (Conv3D)          (None, 15, 75, 75, 32)    4128
#
#  batch_normalization_32 (Bat  (None, 15, 75, 75, 32)   128
#  chNormalization)
#
#  max_pooling3d_25 (MaxPoolin  (None, 7, 37, 37, 32)    0
#  g3D)
#
#  conv3d_33 (Conv3D)          (None, 7, 37, 37, 64)     16448
#
#  batch_normalization_33 (Bat  (None, 7, 37, 37, 64)    256
#  chNormalization)
#
#  max_pooling3d_26 (MaxPoolin  (None, 3, 18, 18, 64)    0
#  g3D)
#
#  conv3d_34 (Conv3D)          (None, 3, 18, 18, 128)    65664
#
#  batch_normalization_34 (Bat  (None, 3, 18, 18, 128)   512
#  chNormalization)
#
#  max_pooling3d_27 (MaxPoolin  (None, 1, 9, 9, 128)     0
#  g3D)
#
#  flatten_6 (Flatten)         (None, 10368)             0
#
#  dense_18 (Dense)            (None, 1000)              10369000
#
#  dropout_12 (Dropout)        (None, 1000)              0
#
#  dense_19 (Dense)            (None, 500)               500500
#
#  dropout_13 (Dropout)        (None, 500)               0
#
#  dense_20 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 10,963,365
# Trainable params: 10,962,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/25
# 17/17 [==============================] - ETA: 0s - loss: 8.6141 - categorical_accuracy: 0.3575Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from
25
# 17/17 [==============================] - ETA: 0s - loss: 0.2875 - categorical_accuracy: 0.8789
# Epoch 00022: val_loss did not improve from 1.05296
# 17/17 [==============================] - 43s 3s/step - loss: 0.2875 - categorical_accuracy: 0.8789 - val_loss: 3.2934 - val_categorical_accuracy: 0.4000 - lr: 1.9531e-06
# Epoch 23/25
# 17/17 [==============================] - ETA: 0s - loss: 0.3468 - categorical_accuracy: 0.8824
# Epoch 00023: val_loss did not improve from 1.05296
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 17/17 [==============================] - 42s 3s/step - loss: 0.3468 - categorical_accuracy: 0.8824 - val_loss: 2.9180 - val_categorical_accuracy: 0.4500 - lr: 1.9531e-06
# Epoch 24/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2667 - categorical_accuracy: 0.8962
# Epoch 00024: val_loss did not improve from 1.05296
# 17/17 [==============================] - 41s 3s/step - loss: 0.2667 - categorical_accuracy: 0.8962 - val_loss: 1.7633 - val_categorical_accuracy: 0.5000 - lr: 9.7656e-07
# Epoch 25/25
# 17/17 [==============================] - ETA: 0s - loss: 0.3609 - categorical_accuracy: 0.8754
# Epoch 00025: val_loss did not improve from 1.05296
# 17/17 [==============================] - 41s 3s/step - loss: 0.3609 - categorical_accuracy: 0.8754 - val_loss: 1.9805 - val_categorical_accuracy: 0.5500 - lr: 9.7656e-07

# %% [markdown]
# #### Model-4 output summary
# - Training accuracy: 87.54
# - Validation accuracy: 55.00
# - Validation loss: 1.98
#
# ### We can observe that compared to image size 120x120 and same epochs though the accuracy and loss is better, but the drop in loss is more smooth.
# ### Training with more number of epochs is needed to compare the output

# %% [markdown]
# # By running different models with different image sizes (120x120 & 150x150) we can observe that:
# - Increasing the batch size definitely helps (40 vs 30)
# - Image size 150x150 with 25 epochs perform better compared to 120x120. It results in better validation loss and training & validation accuracy.
#
# We should experiment the model with more number of samples and epochs before trying out different architecture
#
# #### Before trying with more number of epochs, we should try to run the model with more number of batch size (50) and should see how the model performs better

# %% [markdown]
# # Train model with batch size: 50, epochs: 25 and compare the model with 120x120 & 150x150 image size

# %% [markdown]
# ### Model-5 input summary (Conv3d architecture): Hyper parameter tuning, increased batch size: 50
#
# - input image size(120x120)
# - epochs: 25
# - batch size: 50
#
# In this attempt, try to change the image width/height size and see how it performed compared to previous model in 25 nb of epocs

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_5 = model_architecture(25, 50, 120)
model_5.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_5.execute()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_35 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  batch_normalization_35 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  activation_7 (Activation)   (None, 30, 120, 120, 8)   0
#
#  conv3d_36 (Conv3D)          (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_36 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_28 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_37 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_37 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_29 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_38 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_38 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_30 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_39 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_39 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_31 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_7 (Flatten)         (None, 6272)              0
#
#  dense_21 (Dense)            (None, 1000)              6273000
#
#  dropout_14 (Dropout)        (None, 1000)              0
#
#  dense_22 (Dense)            (None, 500)               500500
#
#  dropout_15 (Dropout)        (None, 500)               0
#
#  dense_23 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 50
# Epoch 1/25
# 14/14 [==============================] - ETA: 0s - loss: 7.7662 - categorical_accuracy: 0.3137Source path =  /home/datasets/Project_data/val ; batch size = 50
#
# Epoch 00001: val_loss did not improve from 1.05296
# 14/14 [==============================] - 90s 6s/step - loss: 7.7662 - categorical_accuracy: 0.3137 - val_loss: 1.4946 - val_categorical_accuracy: 0.3400 - lr: 0.0010
# Epoch
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 14/14 [==============================] - 41s 3s/step - loss: 0.6999 - categorical_accuracy: 0.7692 - val_loss: 4.4592 - val_categorical_accuracy: 0.2067 - lr: 9.7656e-07
# Epoch 24/25
# 14/14 [==============================] - ETA: 0s - loss: 0.7679 - categorical_accuracy: 0.7088
# Epoch 00024: val_loss did not improve from 1.05296
# 14/14 [==============================] - 40s 3s/step - loss: 0.7679 - categorical_accuracy: 0.7088 - val_loss: 4.1575 - val_categorical_accuracy: 0.2067 - lr: 4.8828e-07
# Epoch 25/25
# 14/14 [==============================] - ETA: 0s - loss: 0.7072 - categorical_accuracy: 0.7418
# Epoch 00025: val_loss did not improve from 1.05296
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 14/14 [==============================] - 40s 3s/step - loss: 0.7072 - categorical_accuracy: 0.7418 - val_loss: 3.6693 - val_categorical_accuracy: 0.2133 - lr: 4.8828e-07

# %% [markdown]
# #### Model-5 output summary
# - Training accuracy: 74.18
# - Validation accuracy: 21.33
# - Validation loss: 3.6693
#
# ### We can observe that batch size: 50 does not perform better compared with batch size: 40

# %% [markdown]
# ### Model-6 input summary (Conv3d architecture): With image size (150x150)
#
# - input image size(150x150)
# - epochs: 25
# - batch size: 50
#
# ##### <font color="red"> With higher number of batches, we can notice OOM error. With further resource optimization and increased processing power model can be trained and behavior can be observed.</font>

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_6 = model_architecture(25, 50, 150)
model_6.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_6.execute()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_35 (Conv3D)          (None, 30, 150, 150, 8)   656
#
#  batch_normalization_141 (Ba  (None, 30, 150, 150, 8)  32
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 30, 150, 150, 8)   0
#
#  conv3d_36 (Conv3D)          (None, 30, 150, 150, 16)  3472
#
#  batch_normalization_142 (Ba  (None, 30, 150, 150, 16)  64
#  tchNormalization)
#
#  max_pooling3d_28 (MaxPoolin  (None, 15, 75, 75, 16)   0
#  g3D)
#
#  conv3d_37 (Conv3D)          (None, 15, 75, 75, 32)    4128
#
#  batch_normalization_143 (Ba  (None, 15, 75, 75, 32)   128
#  tchNormalization)
#
#  max_pooling3d_29 (MaxPoolin  (None, 7, 37, 37, 32)    0
#  g3D)
#
#  conv3d_38 (Conv3D)          (None, 7, 37, 37, 64)     16448
#
#  batch_normalization_144 (Ba  (None, 7, 37, 37, 64)    256
#  tchNormalization)
#
#  max_pooling3d_30 (MaxPoolin  (None, 3, 18, 18, 64)    0
#  g3D)
#
#  conv3d_39 (Conv3D)          (None, 3, 18, 18, 128)    65664
#
#  batch_normalization_145 (Ba  (None, 3, 18, 18, 128)   512
#  tchNormalization)
#
#  max_pooling3d_31 (MaxPoolin  (None, 1, 9, 9, 128)     0
#  g3D)
#
#  flatten_29 (Flatten)        (None, 10368)             0
#
#  dense_65 (Dense)            (None, 1000)              10369000
#
#  dropout_58 (Dropout)        (None, 1000)              0
#
#  dense_66 (Dense)            (None, 500)               500500
#
#  dropout_59 (Dropout)        (None, 500)               0
#
#  dense_67 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params:
I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 492800 totalling 481.2KiB
# 2022-05-08 09:29:01.601642: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 587776 totalling 574.0KiB
# 2022-05-08 09:29:01.601650: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 22 Chunks of size 2000128 totalling 41.96MiB
# 2022-05-08 09:29:01.601658: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2430976 totalling 2.32MiB
# 2022-05-08 09:29:01.601665: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 3999232 totalling 3.81MiB
# 2022-05-08 09:29:01.601672: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 6422528 totalling 6.12MiB
# 2022-05-08 09:29:01.601679: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 16000000 totalling 30.52MiB
# 2022-05-08 09:29:01.601686: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 17295616 totalling 16.49MiB
# 2022-05-08 09:29:01.601694: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 18432000 totalling 35.16MiB
# 2022-05-08 09:29:01.601701: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 23625728 totalling 22.53MiB
# 2022-05-08 09:29:01.601709: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 8 Chunks of size 25088000 totalling 191.41MiB
# 2022-05-08 09:29:01.601716: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 27131904 totalling 25.88MiB
# 2022-05-08 09:29:01.601723: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 27554048 totalling 26.28MiB
# 2022-05-08 09:29:01.601731: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 39142912 totalling 37.33MiB
# 2022-05-08 09:29:01.601738: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 41472000 totalling 237.30MiB
# 2022-05-08 09:29:01.601746: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 42020864 totalling 40.07MiB
# 2022-05-08 09:29:01.601753: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 50371328 totalling 48.04MiB
# 2022-05-08 09:29:01.601760: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 76943616 totalling 73.38MiB
# 2022-05-08 09:29:01.601767: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 77233408 totalling 73.66MiB
# 2022-05-08 09:29:01.601775: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 270000128 totalling 772.48MiB
# 2022-05-08 09:29:01.601783: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 405000192 totalling 386.24MiB
# 2022-05-08 09:29:01.601790: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 1080000000 totalling 2.01GiB
# 2022-05-08 09:29:01.601797: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 2160000000 totalling 8.05GiB
# 2022-05-08 09:29:01.601804: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 12.09GiB
# 2022-05-08 09:29:01.601812: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 15522398208 memory_limit_: 15522398208 available bytes: 0 curr_region_allocation_bytes_: 17179869184
# 2022-05-08 09:29:01.601823: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                     15522398208
# InUse:                     12982975488
# MaxInUse:                  12982975488
# NumAllocs:                     3718793
# MaxAllocSize:               2176777216
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-05-08 09:29:01.601902: W tensorflow/core/common_runtime/bfc_allocator.cc:475] *******************************************************************_____********______**************
# 2022-05-08 09:29:01.601950: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at cudnn_pooling_gpu.cc:172 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[50,16,30,150,150] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_451/454466772.py in <module>
#       3 model_6.define_conv3d_architecture_1();
#       4 print('\n\n=========== Training the model ===========\n\n')
# ----> 5 model_6.execute()
#
# /tmp/ipykernel_451/66761623.py in execute(self)
#     204         steps_per_epoch, validation_steps = self.cal_validation_steps_per_epoch()
#     205
# --> 206         history = self.model_arch.fit_generator(train_generator, steps_per_epoch = steps_per_epoch, epochs = self.num_epochs, verbose=1,
#     207                         callbacks = callbacks_list, validation_data = val_generator,
#     208                         validation_steps = validation_steps, class_weight=None, workers=1, initial_epoch=0)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2014         'Please use `Model.fit`, which supports generators.',
#    2015         stacklevel=2)
# -> 2016     return self.fit(
#    2017         generator,
#    2018         steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[50,16,30,150,150] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/sequential_32/max_pooling3d_28/MaxPool3D/MaxPool3DGrad
#  (defined at /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/optimizer_v2.py:464)
# ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_51046]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node gradient_tape/sequential_32/max_pooling3d_28/MaxPool3D/MaxPool3DGrad:
# In[0] sequential_32/batch_normalization_142/FusedBatchNormV3 (defined at /usr/local/lib/python3.8/dist-packages/keras/layers/normalization/batch_normalization.py:589)
# In[1] sequential_32/max_pooling3d_28/MaxPool3D (defined at /usr/local/lib/python3.8/dist-packages/keras/layers/pooling.py:699)
# In[2] gradient_tape/sequential_32/conv3d_37/Conv3D/Conv3DBackpropInputV2:
#
# Operation defined at: (most recent call last)
# >>>   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
# >>>     return _run_code(code, main_globals, None,
# >>>
# >>>   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py", line 16, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 846, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelapp.py", line 677, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 461, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 450, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 357, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 652, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py", line 359, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/ipykernel/zmqshell.py", line 532, in run_cell
# >>>     return super().run_cell(*args, **kwargs)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
# >>>     result = self._run_cell(
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
# >>>     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3457, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "/tmp/ipykernel_451/454466772.py", line 5, in <module>
# >>>     model_6.execute()
# >>>
# >>>   File "/tmp/ipykernel_451/66761623.py", line 206, in execute
# >>>     history = self.model_arch.fit_generator(train_generator, steps_per_epoch = steps_per_epoch, epochs = self.num_epochs, verbose=1,
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 2016, in fit_generator
# >>>     return self.fit(
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1216, in fit
# >>>     tmp_logs = self.train_function(iterator)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 878, in train_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 867, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 860, in run_step
# >>>     outputs = model.train_step(data)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 816, in train_step
# >>>     self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/optimizer_v2.py", line 530, in minimize
# >>>     grads_and_vars = self._compute_gradients(
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/optimizer_v2.py", line 583, in _compute_gradients
# >>>     grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
# >>>
# >>>   File "/usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/optimizer_v2.py", line 464, in _get_gradients
# >>>     grads = tape.gradient(loss, var_list, grad_loss)
# >>>

# %% [markdown]
# # Train model with 50 epochs and compare 120x120, 150x150 image size

# %% [markdown]
# ### Model-7 input summary (Conv3d architecture): Hyper parameter tuning (With epochs 50)
#
# - input image size(120x120)
# - epochs: 50
# - batch size: 40

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_7 = model_architecture(50, 40, 120)
model_7.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_7.execute()
# Out:
# 2022-05-14 14:52:50.416300: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-05-14 14:52:50.416365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14803 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:3f:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 120, 120, 8)   656
#
#  batch_normalization (BatchN  (None, 30, 120, 120, 8)  32
#  ormalization)
#
#  activation (Activation)     (None, 30, 120, 120, 8)   0
#
#  conv3d_1 (Conv3D)           (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_1 (Batc  (None, 30, 120, 120, 16)  64
#  hNormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 60, 60, 16)   0
#  )
#
#  conv3d_2 (Conv3D)           (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_2 (Batc  (None, 15, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_3 (Batc  (None, 7, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  conv3d_4 (Conv3D)           (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_4 (Batc  (None, 3, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 1000)              6273000
#
#  dropout (Dropout)           (None, 1000)              0
#
#  dense_1 (Dense)             (None, 500)               500500
#
#  dropout_1 (Dropout)         (None, 500)               0
#
#  dense_2 (Dense)             (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1
# Epoch 43/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3683 - categorical_accuracy: 0.8581
# Epoch 00043: val_loss did not improve from 0.39392
# 17/17 [==============================] - 76s 5s/step - loss: 0.3683 - categorical_accuracy: 0.8581 - val_loss: 0.4484 - val_categorical_accuracy: 0.8500 - lr: 1.2207e-07
# Epoch 44/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3232 - categorical_accuracy: 0.8685
# Epoch 00044: val_loss did not improve from 0.39392
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 17/17 [==============================] - 77s 5s/step - loss: 0.3232 - categorical_accuracy: 0.8685 - val_loss: 0.6665 - val_categorical_accuracy: 0.8167 - lr: 1.2207e-07
# Epoch 45/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4032 - categorical_accuracy: 0.8547
# Epoch 00045: val_loss did not improve from 0.39392
# 17/17 [==============================] - 76s 5s/step - loss: 0.4032 - categorical_accuracy: 0.8547 - val_loss: 0.4417 - val_categorical_accuracy: 0.8667 - lr: 6.1035e-08
# Epoch 46/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3312 - categorical_accuracy: 0.8754
# Epoch 00046: val_loss did not improve from 0.39392
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 17/17 [==============================] - 76s 5s/step - loss: 0.3312 - categorical_accuracy: 0.8754 - val_loss: 0.5061 - val_categorical_accuracy: 0.8167 - lr: 6.1035e-08
# Epoch 47/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3691 - categorical_accuracy: 0.8720
# Epoch 00047: val_loss did not improve from 0.39392
# 17/17 [==============================] - 76s 5s/step - loss: 0.3691 - categorical_accuracy: 0.8720 - val_loss: 0.5258 - val_categorical_accuracy: 0.8500 - lr: 3.0518e-08
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3299 - categorical_accuracy: 0.8858
# Epoch 00048: val_loss improved from 0.39392 to 0.34872, saving model to model_init_2022-05-1414_51_24.445589/model-00048-0.32990-0.88581-0.34872-0.91667.h5
# 17/17 [==============================] - 75s 5s/step - loss: 0.3299 - categorical_accuracy: 0.8858 - val_loss: 0.3487 - val_categorical_accuracy: 0.9167 - lr: 3.0518e-08
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3395 - categorical_accuracy: 0.8754
# Epoch 00049: val_loss did not improve from 0.34872
# 17/17 [==============================] - 77s 5s/step - loss: 0.3395 - categorical_accuracy: 0.8754 - val_loss: 0.5537 - val_categorical_accuracy: 0.7667 - lr: 3.0518e-08
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3410 - categorical_accuracy: 0.8858
# Epoch 00050: val_loss did not improve from 0.34872
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 17/17 [==============================] - 75s 5s/step - loss: 0.3410 - categorical_accuracy: 0.8858 - val_loss: 0.6372 - val_categorical_accuracy: 0.8000 - lr: 3.0518e-08

# %% [markdown]
# #### Model-7 output summary
# - Training accuracy:  88.58
# - Validation accuracy: 91.67
# - Validation loss: 0.3487
#
# We can observe that training the model with more number of epochs improve the result overall and validation loss comes down to 0.5372

# %% [markdown]
# ### Model-8 input summary (Conv3d architecture): With image size (150x150)
#
# - input image size(150x150)
# - epochs: 50
# - batch size: 40

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_8 = model_architecture(50, 40, 150)
model_8.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_8.execute()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_45 (Conv3D)          (None, 30, 150, 150, 8)   656
#
#  batch_normalization_45 (Bat  (None, 30, 150, 150, 8)  32
#  chNormalization)
#
#  activation_9 (Activation)   (None, 30, 150, 150, 8)   0
#
#  conv3d_46 (Conv3D)          (None, 30, 150, 150, 16)  3472
#
#  batch_normalization_46 (Bat  (None, 30, 150, 150, 16)  64
#  chNormalization)
#
#  max_pooling3d_36 (MaxPoolin  (None, 15, 75, 75, 16)   0
#  g3D)
#
#  conv3d_47 (Conv3D)          (None, 15, 75, 75, 32)    4128
#
#  batch_normalization_47 (Bat  (None, 15, 75, 75, 32)   128
#  chNormalization)
#
#  max_pooling3d_37 (MaxPoolin  (None, 7, 37, 37, 32)    0
#  g3D)
#
#  conv3d_48 (Conv3D)          (None, 7, 37, 37, 64)     16448
#
#  batch_normalization_48 (Bat  (None, 7, 37, 37, 64)    256
#  chNormalization)
#
#  max_pooling3d_38 (MaxPoolin  (None, 3, 18, 18, 64)    0
#  g3D)
#
#  conv3d_49 (Conv3D)          (None, 3, 18, 18, 128)    65664
#
#  batch_normalization_49 (Bat  (None, 3, 18, 18, 128)   512
#  chNormalization)
#
#  max_pooling3d_39 (MaxPoolin  (None, 1, 9, 9, 128)     0
#  g3D)
#
#  flatten_9 (Flatten)         (None, 10368)             0
#
#  dense_27 (Dense)            (None, 1000)              10369000
#
#  dropout_18 (Dropout)        (None, 1000)              0
#
#  dense_28 (Dense)            (None, 500)               500500
#
#  dropout_19 (Dropout)        (None, 500)               0
#
#  dense_29 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 10,963,365
# Trainable params: 10,962,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 8.9812 - categorical_accuracy: 0.3605Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.30067
# 17/17 [==============================] - 104s 6s/step - loss: 8.9812 - categorical_accuracy: 0.3605 - val_loss: 1.4882 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 2.3030 - categorical_accuracy: 0.5524
# Epoch 00002: val_loss did not improve from 0.30067
# 17/17 [==============================] - 70s 4s/step - loss: 2.3030 - categorical_accuracy: 0.5524 - val_loss: 2.2171 - val_categorical_accuracy: 0.2333 - lr: 0.0010
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss: 1.8622 - categorical_accuracy: 0.5586
# Epoch 00003: val_loss did not improve from 0.30067
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] - 61s 4s/step - loss: 1.8622 - categorical_accuracy: 0.5586 - val_loss: 2.6243 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 4/50
# 17/17 [==============================] - ETA: 0s - loss: 1.8292 - categorical_accuracy: 0.6409
# Epoch 00004: val_loss did not improve from 0.30067
# 17/17 [==============================] - 65s 4s/step - loss: 1.8292 - categorical_accuracy: 0.6409 - val_loss: 3.5909 - val_categorical_accuracy: 0.1500 - lr: 5.0000e-04
# Epoch 5/50
# 17/17 [==============================] - ETA: 0s - loss: 1.3117 - categorical_accuracy: 0.6262
# Epoch 00005: val_loss did not improve from 0.30067
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 [==============================] - 57s 4s/step - loss: 1.3117 - categorical_accuracy: 0.6262 - val_loss: 6.3739 - val_categorical_accuracy: 0.1500 - lr: 5.0000e-04
# Epoch 6/50
# 17/17 [==============================] - ETA: 0s - loss: 0.9530 - categorical_accuracy: 0.7370
# Epoch 00006: val_loss did not improve from 0.30067
# 17/17 [==============================] - 56s 4s/step - loss: 0.9530 - categorical_accuracy: 0.7370 - val_loss: 5.8429 - val_categorical_accuracy: 0.1333 - lr: 2.5000e-04
# Epoch 7/50
# 17/17 [==============================] - ETA: 0s - loss: 0.8640 - categorical_accuracy: 0.7301
# Epoch 00007: val_loss did not improve from 0.30067
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 [==============================] - 51s 3s/step - loss: 0.8640 - categorical_accuracy: 0.7301 - val_loss: 6.1231 - val_categorical_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 8/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5488 - categorical_accuracy: 0.8028
# Epoch 00008: val_loss did not improve from 0.30067
# 17/17 [==============================] - 57s 4s/step - loss: 0.5488 - categorical_accuracy: 0.8028 - val_loss: 6.0518 - val_categorical_accuracy: 0.2333 - lr: 1.2500e-04
# Epoch 9/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5918 - categorical_accuracy: 0.7993
# Epoch 00009: val_loss did not improve from 0.30067
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 17/17 [==============================] - 49s 3s/step - loss: 0.5918 - categorical_accuracy: 0.7993 - val_loss: 6.4770 - val_categorical_accuracy: 0.2000 - lr: 1.2500e-04
# Epoch 10/50
# 17/17 [==============================] - ETA: 0s - loss: 0.
# Epoch 47/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3725 - categorical_accuracy: 0.8685
# Epoch 00047: val_loss did not improve from 0.30067
# 17/17 [==============================] - 47s 3s/step - loss: 0.3725 - categorical_accuracy: 0.8685 - val_loss: 0.4332 - val_categorical_accuracy: 0.8333 - lr: 7.6294e-09
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3948 - categorical_accuracy: 0.8512
# Epoch 00048: val_loss did not improve from 0.30067
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 17/17 [==============================] - 47s 3s/step - loss: 0.3948 - categorical_accuracy: 0.8512 - val_loss: 0.6306 - val_categorical_accuracy: 0.7667 - lr: 7.6294e-09
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4184 - categorical_accuracy: 0.8408
# Epoch 00049: val_loss did not improve from 0.30067
# 17/17 [==============================] - 42s 3s/step - loss: 0.4184 - categorical_accuracy: 0.8408 - val_loss: 0.3635 - val_categorical_accuracy: 0.8167 - lr: 3.8147e-09
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3936 - categorical_accuracy: 0.8443
# Epoch 00050: val_loss did not improve from 0.30067
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 17/17 [==============================] - 42s 3s/step - loss: 0.3936 - categorical_accuracy: 0.8443 - val_loss: 0.3722 - val_categorical_accuracy: 0.8500 - lr: 3.8147e-09

# %% [markdown]
# #### Model-8 output summary
# - Training accuracy: 84.43
# - Validation accuracy: 85.00
# - Validation loss: 0.3722
#
# We can observe that training the model with Image size (150x150) gives us the similar result compared to image size: 120x120 and both the model performs better
#
# ##### Going further, model with different layer of archtectures can be trained with 120x120 image sizes

# %% [markdown]
# ## Trying different architecture(2) -(Conv3d architecture): With image size (120x120)
#
# #### Model-9 (Image-size 120x120)
# - num_epoch: 25
# - batch_size: 40
# - image_size: 120x120
#
# ##### Model training with less number of epochs

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_9 = model_architecture(25, 40, 120)
model_9.define_conv3d_architecture_2();
print('\n\n=========== Training the model ===========\n\n')
model_9.execute()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_50 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  batch_normalization_50 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  activation_10 (Activation)  (None, 30, 120, 120, 8)   0
#
#  conv3d_51 (Conv3D)          (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_51 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_40 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_52 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_52 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_41 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  dropout_20 (Dropout)        (None, 7, 30, 30, 32)     0
#
#  conv3d_53 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_53 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_42 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  dropout_21 (Dropout)        (None, 3, 15, 15, 64)     0
#
#  conv3d_54 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_54 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_43 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  dropout_22 (Dropout)        (None, 1, 7, 7, 128)      0
#
#  flatten_10 (Flatten)        (None, 6272)              0
#
#  dense_30 (Dense)            (None, 1000)              6273000
#
#  dropout_23 (Dropout)        (None, 1000)              0
#
#  dense_31 (Dense)            (None, 500)               500500
#
#  dropout_24 (Dropout)        (None, 500)               0
#
#  dense_32 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/25
# 17/17 [==============================] - ETA: 0s - loss: 9.7257 - categorical_accuracy: 0.2685Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.30067
# 17/17 [==============================] - 79s 5s/step - loss: 9.7257 - categorical_accuracy: 0.2685 - val_loss: 3.6872 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/25
# 17/17 [==============================] - ETA: 0s - loss: 2.5003 - categorical_accuracy: 0.4271
# Epoch 00002: val_loss did not improve from 0.30067
# 17/17 [==============================] - 49s 3s/step - loss: 2.5003 - categorical_accuracy: 0.4271 - val_loss: 5.2113 - val_categorical_accuracy: 0.1833 - lr: 0.0010
# Epoch 3/25
# 17/17 [==============================] - ETA: 0s - loss: 1.7666 - categorical_accuracy: 0.5204
# Epoch 00003: val_loss did not improve from 0.30067
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] -
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 17/17 [==============================] - 38s 2s/step - loss: 0.7267 - categorical_accuracy: 0.7093 - val_loss: 11.4840 - val_categorical_accuracy: 0.2500 - lr: 4.8828e-07

# %% [markdown]
# #### Model-9 output summary
# - Training accuracy: 70.93
# - Validation accuracy: 25.00
# - Validation loss: 11.4840
#
# Deep learning models are evaluated should be based on the loss. We can see the model validation loss is very high 11.4840 compared to architecture-1.

# %% [markdown]
# ## Trying different architecture(3) -(Conv3d architecture): With image size (120x120)
#
# #### Model-10 Input summary (Image-size 120x120)
# - num_epoch: 25
# - batch_size: 40
# - image_size: 120x120
#
# ##### Model training with less number of epochs

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_10 = model_architecture(25, 40, 120)
model_10.define_conv3d_architecture_3();
print('\n\n=========== Training the model ===========\n\n')
model_10.execute()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_55 (Conv3D)          (None, 30, 120, 120, 16)  1312
#
#  batch_normalization_55 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_44 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_56 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_56 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_45 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_57 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_57 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_46 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_58 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_58 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_47 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  dropout_25 (Dropout)        (None, 1, 7, 7, 128)      0
#
#  flatten_11 (Flatten)        (None, 6272)              0
#
#  dense_33 (Dense)            (None, 1000)              6273000
#
#  dropout_26 (Dropout)        (None, 1000)              0
#
#  dense_34 (Dense)            (None, 500)               500500
#
#  dropout_27 (Dropout)        (None, 500)               0
#
#  dense_35 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,864,517
# Trainable params: 6,864,037
# Non-trainable params: 480
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/25
# 17/17 [==============================] - ETA: 0s - loss: 6.5739 - categorical_accuracy: 0.3243Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.30067
# 17/17 [==============================] - 82s 5s/step - loss: 6.5739 - categorical_accuracy: 0.3243 - val_loss: 2.0203 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch 2/25
# 17/17 [==============================] - ETA: 0s - loss: 1.5319 - categorical_accuracy: 0.5371
# Epoch 00002: val_loss did not improve from 0.30067
# 17/17 [==============================] - 49s 3s/step - loss: 1.5319 - categorical_accuracy: 0.5371 - val_loss: 2.4721 - val_categorical_accuracy: 0.1333 - lr: 0.0010
# Epoch 3/25
# 17/17 [==============================] - ETA: 0s - loss: 1.1093 - categorical_accuracy: 0.6076
# Epoch 00003: val_loss did not improve from 0.30067
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] - 49s 3s/step - loss: 1.1093 - categorical_accuracy: 0.6076 - val_loss: 4.2677 - val_categorical_accuracy: 0.1833 - lr: 0.0010
# Epoch 4/25
# 17/17 [==============================] - ETA: 0s - loss: 0.7795 - categorical_accuracy: 0.7152
# Epoch 00004: val_loss did not improve from 0.30067
# 17/17 [==============================] - 42s 3s/step - loss: 0.7795 - categorical_accuracy: 0.7152 - val_loss: 6.2023 - val_categorical_accuracy: 0.1167 - lr: 5.0000e-04
# Epoch 5/25
# 17/17 [==============================] - ETA: 0s - loss: 0.9165 - categorical_accuracy: 0.6933
# Epoch 00005: val_loss did not improve from 0.30067
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 [==============================] - 42s 3s/step - loss: 0.9165 - categorical_accuracy: 0.6933 - val_loss: 4.4229 - val_categorical_accuracy: 0.2167 - lr: 5.0000e-04
# Epoch 6/25
# 17/17 [==============================] - ETA: 0s - loss: 0.7693 - categorical_accuracy: 0.7370
# Epoch 00006: val_loss did not improve from 0.30067
# 17/17 [==============================] - 40s 3s/step - loss: 0.7693 - categorical_accuracy: 0.7370 - val_loss: 5.5504 - val_categorical_accuracy: 0.1667 - lr: 2.5000e-04
# Epoch 7/25
# 17/17 [==============================] - ETA: 0s - loss: 0.5768 - categorical_accuracy: 0.7993
# Epoch 00007: val_loss did not improve from 0.30067
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 [==============================] -
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 17/17 [==============================] - 36s 2s/step - loss: 0.3226 - categorical_accuracy: 0.8997 - val_loss: 3.5169 - val_categorical_accuracy: 0.2500 - lr: 3.9063e-06
# Epoch 20/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2769 - categorical_accuracy: 0.8962
# Epoch 00020: val_loss did not improve from 0.30067
# 17/17 [==============================] - 39s 2s/step - loss: 0.2769 - categorical_accuracy: 0.8962 - val_loss: 2.9806 - val_categorical_accuracy: 0.3500 - lr: 1.9531e-06
# Epoch 21/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2620 - categorical_accuracy: 0.9031
# Epoch 00021: val_loss did not improve from 0.30067
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 17/17 [==============================] - 39s 2s/step - loss: 0.2620 - categorical_accuracy: 0.9031 - val_loss: 2.9350 - val_categorical_accuracy: 0.3167 - lr: 1.9531e-06
# Epoch 22/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2562 - categorical_accuracy: 0.9239
# Epoch 00022: val_loss did not improve from 0.30067
# 17/17 [==============================] - 39s 2s/step - loss: 0.2562 - categorical_accuracy: 0.9239 - val_loss: 2.9282 - val_categorical_accuracy: 0.2667 - lr: 9.7656e-07
# Epoch 23/25
# 17/17 [==============================] - ETA: 0s - loss: 0.3085 - categorical_accuracy: 0.8858
# Epoch 00023: val_loss did not improve from 0.30067
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 17/17 [==============================] - 40s 2s/step - loss: 0.3085 - categorical_accuracy: 0.8858 - val_loss: 2.8050 - val_categorical_accuracy: 0.3333 - lr: 9.7656e-07
# Epoch 24/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2713 - categorical_accuracy: 0.8927
# Epoch 00024: val_loss did not improve from 0.30067
# 17/17 [==============================] - 39s 2s/step - loss: 0.2713 - categorical_accuracy: 0.8927 - val_loss: 1.9392 - val_categorical_accuracy: 0.4500 - lr: 4.8828e-07
# Epoch 25/25
# 17/17 [==============================] - ETA: 0s - loss: 0.2520 - categorical_accuracy: 0.8997
# Epoch 00025: val_loss did not improve from 0.30067
# 17/17 [==============================] - 40s 2s/step - loss: 0.2520 - categorical_accuracy: 0.8997 - val_loss: 2.0271 - val_categorical_accuracy: 0.3500 - lr: 4.8828e-07

# %% [markdown]
# ### Model-10 output summary
# - Training accuracy: 89.97
# - Validation accuracy: 35.00
# - Validation loss: 2.0271
#
# ### Compared to architecture-1, with same number of epochs, batch size archiecture-3 does not seem to be a better fit and validation loss is comparatively high

# %% [markdown]
# #### Model-10 (Variant) Input summary (Image-size 120x120) - Hyper parameter tuned (epochs: 50)
# - num_epoch: 50
# - batch_size: 40
# - image_size: 120x120
#
# ##### Model training with less number of epochs

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_10_2 = model_architecture(50, 40, 120)
model_10_2.define_conv3d_architecture_3();
print('\n\n=========== Training the model ===========\n\n')
model_10_2.execute()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 30, 120, 120, 16)  1312
#
#  batch_normalization_40 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_41 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_17 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_42 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_18 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_23 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_43 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  dropout_16 (Dropout)        (None, 1, 7, 7, 128)      0
#
#  flatten_8 (Flatten)         (None, 6272)              0
#
#  dense_21 (Dense)            (None, 1000)              6273000
#
#  dropout_17 (Dropout)        (None, 1000)              0
#
#  dense_22 (Dense)            (None, 500)               500500
#
#  dropout_18 (Dropout)        (None, 500)               0
#
#  dense_23 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,864,517
# Trainable params: 6,864,037
# Non-trainable params: 480
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 6.0452 - categorical_accuracy: 0.3529Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.33532
# 17/17 [==============================] - 80s 5s/step - loss: 6.0452 - categorical_accuracy: 0.3529 - val_loss: 1.6561 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss:
val_loss did not improve from 0.33532
# 17/17 [==============================] - 38s 2s/step - loss: 0.3412 - categorical_accuracy: 0.8616 - val_loss: 0.8111 - val_categorical_accuracy: 0.6667 - lr: 1.5259e-08
# Epoch 45/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3118 - categorical_accuracy: 0.8651
# Epoch 00045: val_loss did not improve from 0.33532
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 17/17 [==============================] - 39s 2s/step - loss: 0.3118 - categorical_accuracy: 0.8651 - val_loss: 0.7516 - val_categorical_accuracy: 0.7000 - lr: 1.5259e-08
# Epoch 46/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3547 - categorical_accuracy: 0.8720
# Epoch 00046: val_loss did not improve from 0.33532
# 17/17 [==============================] - 36s 2s/step - loss: 0.3547 - categorical_accuracy: 0.8720 - val_loss: 0.5128 - val_categorical_accuracy: 0.8000 - lr: 7.6294e-09
# Epoch 47/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3118 - categorical_accuracy: 0.8581
# Epoch 00047: val_loss did not improve from 0.33532
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 17/17 [==============================] - 39s 2s/step - loss: 0.3118 - categorical_accuracy: 0.8581 - val_loss: 0.6685 - val_categorical_accuracy: 0.7667 - lr: 7.6294e-09
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3143 - categorical_accuracy: 0.9066
# Epoch 00048: val_loss did not improve from 0.33532
# 17/17 [==============================] - 38s 2s/step - loss: 0.3143 - categorical_accuracy: 0.9066 - val_loss: 0.6303 - val_categorical_accuracy: 0.7500 - lr: 3.8147e-09
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3182 - categorical_accuracy: 0.8927
# Epoch 00049: val_loss did not improve from 0.33532
# 17/17 [==============================] - 38s 2s/step - loss: 0.3182 - categorical_accuracy: 0.8927 - val_loss: 0.4952 - val_categorical_accuracy: 0.8167 - lr: 3.8147e-09
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3080 - categorical_accuracy: 0.8858
# Epoch 00050: val_loss did not improve from 0.33532
# 17/17 [==============================] - 39s 2s/step - loss: 0.3080 - categorical_accuracy: 0.8858 - val_loss: 0.8010 - val_categorical_accuracy: 0.7000 - lr: 3.8147e-09

# %% [markdown]
# ### Model-10 variant output summary
# - Training accuracy: 88.58
# - Validation accuracy: 70.00
# - Validation loss: 0.8010
#
# ### Compared to architecture-1, with same number of epochs, batch size archiecture-3 does not seem to be a better fit and validation loss is comparatively high

# %% [markdown]
# ## Trying different architecture(1) - SGD Variant -(Conv3d architecture): With image size (120x120)
#
# #### Model-11 Input summary (Image-size 120x120)
# - num_epoch: 50
# - batch_size: 40
# - image_size: 120x120
#
# ##### Model training with less number of epochs

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_11 = model_architecture(50, 40, 120)
model_11.define_conv3d_architecture_1_sgd_variant();
print('\n\n=========== Training the model ===========\n\n')
model_11.execute()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_5 (Conv3D)           (None, 30, 120, 120, 8)   656
#
#  batch_normalization_25 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  activation_1 (Activation)   (None, 30, 120, 120, 8)   0
#
#  conv3d_6 (Conv3D)           (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_26 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 15, 60, 60, 16)   0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_27 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_8 (Conv3D)           (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_28 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_29 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#  dense_11 (Dense)            (None, 1000)              6273000
#
#  dropout_10 (Dropout)        (None, 1000)              0
#
#  dense_12 (Dense)            (None, 500)               500500
#
#  dropout_11 (Dropout)        (None, 500)               0
#
#  dense_13 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 3.2865 - categorical_accuracy: 0.2715Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.44253
# 17/17 [==============================] - 76s 5s/step - loss: 3.2865 - categorical_accuracy: 0.2715 - val_loss: 1.5770 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 1.9935 - categorical_accuracy: 0.3453
# Epoch 00002: val_loss did not improve from 0.44253
# 17/17 [==============================] - 48s 3s/step - loss: 1.9935 - categorical_accuracy: 0.3453 - val_loss: 1.4976 - val_categorical_accuracy: 0.3167 - lr: 0.0010
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss:
# Epoch 46/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5414 - categorical_accuracy: 0.8062
# Epoch 00046: val_loss did not improve from 0.44253
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 17/17 [==============================] - 37s 2s/step - loss: 0.5414 - categorical_accuracy: 0.8062 - val_loss: 0.5968 - val_categorical_accuracy: 0.7833 - lr: 6.1035e-08
# Epoch 47/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4807 - categorical_accuracy: 0.8131
# Epoch 00047: val_loss did not improve from 0.44253
# 17/17 [==============================] - 36s 2s/step - loss: 0.4807 - categorical_accuracy: 0.8131 - val_loss: 0.5966 - val_categorical_accuracy: 0.8333 - lr: 3.0518e-08
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5586 - categorical_accuracy: 0.7889
# Epoch 00048: val_loss did not improve from 0.44253
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 17/17 [==============================] - 36s 2s/step - loss: 0.5586 - categorical_accuracy: 0.7889 - val_loss: 0.5266 - val_categorical_accuracy: 0.8333 - lr: 3.0518e-08
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5910 - categorical_accuracy: 0.7682
# Epoch 00049: val_loss did not improve from 0.44253
# 17/17 [==============================] - 39s 2s/step - loss: 0.5910 - categorical_accuracy: 0.7682 - val_loss: 0.5620 - val_categorical_accuracy: 0.8167 - lr: 1.5259e-08
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5212 - categorical_accuracy: 0.8131
# Epoch 00050: val_loss did not improve from 0.44253
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 17/17 [==============================] - 36s 2s/step - loss: 0.5212 - categorical_accuracy: 0.8131 - val_loss: 0.5227 - val_categorical_accuracy: 0.8500 - lr: 1.5259e-08

# %% [markdown]
# ### Model-11 output summary
# - Training accuracy: 81.31
# - Validation accuracy: 85.00
# - Validation loss: 0.5277
#
# Compared to architecture-1, with same number of epochs, batch size archiecture-3 does not seem to be a better fit.

# %% [markdown]
# ## Model 12 : Conv2D & LSTM architecture
#
# - batch-size:40
# - epochs: 50
# - Image-size: 120x120

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_12 = model_architecture(50, 40, 120)
model_12.define_rnn_lstm_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_12.execute()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_32 (TimeDi  (None, 30, 120, 120, 8)  224
#  stributed)
#
#  time_distributed_33 (TimeDi  (None, 30, 120, 120, 8)  32
#  stributed)
#
#  time_distributed_34 (TimeDi  (None, 30, 60, 60, 8)    0
#  stributed)
#
#  time_distributed_35 (TimeDi  (None, 30, 60, 60, 16)   1168
#  stributed)
#
#  time_distributed_36 (TimeDi  (None, 30, 60, 60, 16)   64
#  stributed)
#
#  time_distributed_37 (TimeDi  (None, 30, 30, 30, 16)   0
#  stributed)
#
#  time_distributed_38 (TimeDi  (None, 30, 30, 30, 32)   4640
#  stributed)
#
#  time_distributed_39 (TimeDi  (None, 30, 30, 30, 32)   128
#  stributed)
#
#  time_distributed_40 (TimeDi  (None, 30, 15, 15, 32)   0
#  stributed)
#
#  time_distributed_41 (TimeDi  (None, 30, 15, 15, 64)   18496
#  stributed)
#
#  time_distributed_42 (TimeDi  (None, 30, 15, 15, 64)   256
#  stributed)
#
#  time_distributed_43 (TimeDi  (None, 30, 7, 7, 64)     0
#  stributed)
#
#  time_distributed_44 (TimeDi  (None, 30, 7, 7, 128)    73856
#  stributed)
#
#  time_distributed_45 (TimeDi  (None, 30, 7, 7, 128)    512
#  stributed)
#
#  time_distributed_46 (TimeDi  (None, 30, 3, 3, 128)    0
#  stributed)
#
#  time_distributed_47 (TimeDi  (None, 30, 1152)         0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 256)               1442816
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1
val_loss did not improve from 0.72917
# 17/17 [==============================] - 37s 2s/step - loss: 0.4064 - categorical_accuracy: 0.8789 - val_loss: 1.1042 - val_categorical_accuracy: 0.6167 - lr: 7.6294e-09
# Epoch 43/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3815 - categorical_accuracy: 0.8754
# Epoch 00043: val_loss did not improve from 0.72917
# 17/17 [==============================] - 38s 2s/step - loss: 0.3815 - categorical_accuracy: 0.8754 - val_loss: 0.7742 - val_categorical_accuracy: 0.7000 - lr: 7.6294e-09
# Epoch 44/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4048 - categorical_accuracy: 0.8685
# Epoch 00044: val_loss did not improve from 0.72917
# 17/17 [==============================] - 36s 2s/step - loss: 0.4048 - categorical_accuracy: 0.8685 - val_loss: 0.8313 - val_categorical_accuracy: 0.6833 - lr: 7.6294e-09
# Epoch 45/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3828 - categorical_accuracy: 0.8824
# Epoch 00045: val_loss did not improve from 0.72917
# 17/17 [==============================] - 36s 2s/step - loss: 0.3828 - categorical_accuracy: 0.8824 - val_loss: 0.7377 - val_categorical_accuracy: 0.7500 - lr: 7.6294e-09
# Epoch 46/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3459 - categorical_accuracy: 0.8997
# Epoch 00046: val_loss did not improve from 0.72917
# 17/17 [==============================] - 37s 2s/step - loss: 0.3459 - categorical_accuracy: 0.8997 - val_loss: 0.8641 - val_categorical_accuracy: 0.6500 - lr: 7.6294e-09
# Epoch 47/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4044 - categorical_accuracy: 0.8824
# Epoch 00047: val_loss did not improve from 0.72917
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 17/17 [==============================] - 37s 2s/step - loss: 0.4044 - categorical_accuracy: 0.8824 - val_loss: 0.8826 - val_categorical_accuracy: 0.6000 - lr: 7.6294e-09
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3374 - categorical_accuracy: 0.8997
# Epoch 00048: val_loss did not improve from 0.72917
# 17/17 [==============================] - 38s 2s/step - loss: 0.3374 - categorical_accuracy: 0.8997 - val_loss: 0.7797 - val_categorical_accuracy: 0.6667 - lr: 3.8147e-09
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4123 - categorical_accuracy: 0.8824
# Epoch 00049: val_loss did not improve from 0.72917
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 17/17 [==============================] - 36s 2s/step - loss: 0.4123 - categorical_accuracy: 0.8824 - val_loss: 1.0410 - val_categorical_accuracy: 0.5667 - lr: 3.8147e-09
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.3769 - categorical_accuracy: 0.8893
# Epoch 00050: val_loss improved from 0.72917 to 0.64900, saving model to model_init_2022-05-1401_02_12.006339/model-00050-0.37695-0.88927-0.64900-0.75000.h5
# 17/17 [==============================] - 36s 2s/step - loss: 0.3769 - categorical_accuracy: 0.8893 - val_loss: 0.6490 - val_categorical_accuracy: 0.7500 - lr: 1.9073e-09

# %% [markdown]
# ### Model-12 output summary
# - Training accuracy  : 88.93
# - Validation accuracy: 75.00
# - Validation loss : 0.6490
#
# ### Compared to architecture 1 (conv3D) architecture, though the architecture is fairly comparable with 50 epochs, but the validation loss & accuracy converges more fast in conv3d architecture compared to LSTM. Different variant of architecture should be tried to see the output.

# %% [markdown]
# ## Model 13: Conv2D & GPU architecture (Image size: 120x120, epochs: 50)
#
# - batch-size:40
# - epochs: 50
# - Image-size: 120x120

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_13 = model_architecture(50, 40, 120)
model_13.define_rnn_gru_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_13.execute()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_48 (TimeDi  (None, 30, 120, 120, 8)  224
#  stributed)
#
#  time_distributed_49 (TimeDi  (None, 30, 120, 120, 8)  32
#  stributed)
#
#  time_distributed_50 (TimeDi  (None, 30, 60, 60, 8)    0
#  stributed)
#
#  time_distributed_51 (TimeDi  (None, 30, 60, 60, 16)   1168
#  stributed)
#
#  time_distributed_52 (TimeDi  (None, 30, 60, 60, 16)   64
#  stributed)
#
#  time_distributed_53 (TimeDi  (None, 30, 30, 30, 16)   0
#  stributed)
#
#  time_distributed_54 (TimeDi  (None, 30, 30, 30, 32)   4640
#  stributed)
#
#  time_distributed_55 (TimeDi  (None, 30, 30, 30, 32)   128
#  stributed)
#
#  time_distributed_56 (TimeDi  (None, 30, 15, 15, 32)   0
#  stributed)
#
#  time_distributed_57 (TimeDi  (None, 30, 15, 15, 64)   18496
#  stributed)
#
#  time_distributed_58 (TimeDi  (None, 30, 15, 15, 64)   256
#  stributed)
#
#  time_distributed_59 (TimeDi  (None, 30, 7, 7, 64)     0
#  stributed)
#
#  time_distributed_60 (TimeDi  (None, 30, 7, 7, 128)    73856
#  stributed)
#
#  time_distributed_61 (TimeDi  (None, 30, 7, 7, 128)    512
#  stributed)
#
#  time_distributed_62 (TimeDi  (None, 30, 3, 3, 128)    0
#  stributed)
#
#  time_distributed_63 (TimeDi  (None, 30, 1152)         0
#  stributed)
#
#  gru_1 (GRU)                 (None, 256)               1082880
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1,215,797
# Trainable params: 1,215,301
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 1.4337 - categorical_accuracy: 0.3982Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.64900
# 17/17 [==============================] - 79s 5s/step - loss: 1.4337 - categorical_accuracy: 0.3982 - val_loss: 1.6788 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 0.9574 - categorical_accuracy: 0.6496
# Epoch 00002: val_loss did not improve from 0.64900
# 17/17 [==============================] - 47s 3s/step - loss: 0.9574 - categorical_accuracy: 0.6496 - val_loss: 2.0494 - val_categorical_accuracy: 0.2667 - lr: 0.0010
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss: 0.8457 - categorical_accuracy: 0.6676
# Epoch 00003: val_loss did not improve from 0.64900
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] - 42s 3s/step - loss: 0.8457 - categorical_accuracy: 0.6676 - val_loss: 2.2732 - val_categorical_accuracy: 0.2167 - lr: 0.0010
# Epoch 4/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6243 - categorical_accuracy: 0.7647
# Epoch 00004: val_loss did not improve from 0.64900
# 17/17 [==============================] - 40s 2s/step - loss: 0.6243 - categorical_accuracy: 0.7647 - val_loss: 2.3158 - val_categorical_accuracy: 0.1833 - lr: 5.0000e-04
# Epoch 5/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5799 - categorical_accuracy: 0.7700
# Epoch 00005: val_loss did not improve from 0.64900
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 [==============================] - 41s 3s/step - loss: 0.5799 - categorical_accuracy: 0.7700 - val_loss: 2.9621 - val_categorical_accuracy: 0.2167 - lr: 5.0000e-04
# Epoch 6/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4071 - categorical_accuracy: 0.8581
# Epoch 00006: val_loss did not improve from 0.64900
# 17/17 [==============================] - 35s 2s/step - loss: 0.4071 - categorical_accuracy: 0.8581 - val_loss: 2.6806 - val_categorical_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 7/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4020 - categorical_accuracy: 0.8581
# Epoch 00007: val_loss did not improve from 0.64900
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 [==============================] - 37s 2s/step - loss: 0.4020 - categorical_accuracy: 0.8581 - val_loss: 3.0810 - val_categorical_accuracy: 0.2167 - lr: 2.5000e-04
# Epoch 8/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2412 - categorical_accuracy: 0.9273
# Epoch 00008: val_loss did not improve from 0.64900
# 17/17 [==============================] - 36s 2s/step - loss: 0.2412 - categorical_accuracy: 0.9273 - val_loss: 2.8436 - val_categorical_accuracy: 0.2167 - lr: 1.2500e-04
# Epoch 9/50
# 17/17 [==============================] - ETA: 0s - loss: 0.2368 - categorical_accuracy: 0.9343
# Epoch 00009: val_loss did not improve from 0.64900
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 17/17 [==============================] -
# Epoch 48/50
# 17/17 [==============================] - ETA: 0s - loss: 0.1509 - categorical_accuracy: 0.9792
# Epoch 00048: val_loss did not improve from 0.46885
# 17/17 [==============================] - 37s 2s/step - loss: 0.1509 - categorical_accuracy: 0.9792 - val_loss: 0.6338 - val_categorical_accuracy: 0.8000 - lr: 7.6294e-09
# Epoch 49/50
# 17/17 [==============================] - ETA: 0s - loss: 0.1221 - categorical_accuracy: 0.9758
# Epoch 00049: val_loss improved from 0.46885 to 0.44253, saving model to model_init_2022-05-1401_02_12.006339/model-00049-0.12210-0.97578-0.44253-0.85000.h5
# 17/17 [==============================] - 39s 2s/step - loss: 0.1221 - categorical_accuracy: 0.9758 - val_loss: 0.4425 - val_categorical_accuracy: 0.8500 - lr: 7.6294e-09
# Epoch 50/50
# 17/17 [==============================] - ETA: 0s - loss: 0.1392 - categorical_accuracy: 0.9758
# Epoch 00050: val_loss did not improve from 0.44253
# 17/17 [==============================] - 35s 2s/step - loss: 0.1392 - categorical_accuracy: 0.9758 - val_loss: 0.5572 - val_categorical_accuracy: 0.8167 - lr: 7.6294e-09

# %% [markdown]
# ### Model-13 output summary
# - Training accuracy  : 97.58
# - Validation accuracy: 85.00
# - Validation loss : 0.4425
#
# ### Compared to LSTM architecture, GPU architecture and model seemed to perform better. GPU architecture can be tried out with different number of layers and output can be compared.
#
# ### With current architecturs/set of layers overall Conv3d architecture was better compared to LSTM/GPU.

# %% [markdown]
# # Data Augmentation: Training the best model with data augmentation (affine strategy) to see the output

# %%
x = 30 # No. of frames images
def generator_with_data_augmentation(source_path, folder_list, batch_size, width=120, height=120):
    img_idx = [x for x in range(0,x)] #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size, x, width, height, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # Let us resize all the images 
                    
                    shifted = cv2.warpAffine(image, np.float32([[1, 0, np.random.randint(-20,20)],[0, 1, np.random.randint(-20,20)]]),(image.shape[1], image.shape[0]))
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1, y0:y1, :]
                    
                    resized_image = resize(cropped,(width, height))
                    resized_image = resized_image/255
                    
                    batch_data[folder,idx,:,:,0] = (resized_image[:,:,0])#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (resized_image[:,:,1])#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (resized_image[:,:,2])#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches        
        if (len(folder_list) != batch_size*num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x, width, z, 3))
            batch_labels = np.zeros((batch_size,5))  
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0])
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    shifted = cv2.warpAffine(image, np.float32([[1, 0, np.random.randint(-20,20)],[0, 1, np.random.randint(-20,20)]]),(image.shape[1], image.shape[0]))
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    resized_image = resize(cropped,(width, height))
                    resized_image = resized_image/255
                                        
                    batch_data[folder,idx,:,:,0] = (resized_image[:,:,0])
                    batch_data[folder,idx,:,:,1] = (resized_image[:,:,1])
                    batch_data[folder,idx,:,:,2] = (resized_image[:,:,2])
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %%
class model_architecture_data_augmentation:
    # initialize default parameter
    num_epochs = 25
    batch_size = 40
    image_width_height = 120
    
    #defining constructor  
    def __init__(self, num_epochs = 15, batch_size = 40, image_width_height = 120):  
        self.num_epochs = num_epochs  
        self.batch_size = batch_size 
        self.image_width_height = image_width_height
        
    def define_conv3d_architecture_1(self):
        model_arch_1 = Sequential()       
        model_arch_1.add(Conv3D(8,kernel_size=(3,3,3),input_shape=(30, self.image_width_height, self.image_width_height, 3),padding='same'))
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(Activation('relu'))

        model_arch_1.add(Conv3D(16, (3, 3, 3), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(32, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(64, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model_arch_1.add(Conv3D(128, (2, 2, 2), activation='relu', padding='same')) 
        model_arch_1.add(BatchNormalization())
        model_arch_1.add(MaxPooling3D(pool_size=(2, 2, 2)))      

        # Flatten layer 
        model_arch_1.add(Flatten())
        model_arch_1.add(Dense(1000, activation='relu'))
        model_arch_1.add(Dropout(0.5))

        model_arch_1.add(Dense(500, activation='relu'))
        model_arch_1.add(Dropout(0.5))

        #Softmax layer
        model_arch_1.add(Dense(5, activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.001) #write your optimizer
        model_arch_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        print (model_arch_1.summary())

        self.model_arch = model_arch_1
       
    def cal_validation_steps_per_epoch(self):
        if (num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (num_train_sequences//self.batch_size) + 1

        if (num_val_sequences%batch_size) == 0:
            validation_steps = int(num_val_sequences/self.batch_size)
        else:
            validation_steps = (num_val_sequences//self.batch_size) + 1

        return steps_per_epoch, validation_steps

    def plot(self, history):
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
        axes[0].plot(history.history['loss'])   
        axes[0].plot(history.history['val_loss'])
        axes[0].grid()
        axes[0].legend(['loss','val_loss'])
        axes[1].plot(history.history['categorical_accuracy'])   
        axes[1].plot(history.history['val_categorical_accuracy'])
        axes[1].grid()
        axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    
    def execute(self):
        # Now that you have defined the model in define_conv3d_architecture_1, the next step is to `compile` the model. 
        # When you print the `summary` of the model, you'll see the total number of parameters you have to train.
        train_generator = generator_with_data_augmentation(train_path, train_doc, self.batch_size, self.image_width_height, self.image_width_height)
        val_generator = generator_with_data_augmentation(val_path, val_doc, self.batch_size, self.image_width_height, self.image_width_height)

        #The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
        steps_per_epoch, validation_steps = self.cal_validation_steps_per_epoch()

        history = self.model_arch.fit_generator(train_generator, steps_per_epoch = steps_per_epoch, epochs = self.num_epochs, verbose=1, 
                        callbacks = callbacks_list, validation_data = val_generator, 
                        validation_steps = validation_steps, class_weight=None, workers=1, initial_epoch=0)
        self.plot(history)
        
        return history

# %% [markdown]
# ## Model 14: Conv3D architecture (Image size: 120x120, epochs: 50)
#
# - batch-size:40
# - epochs: 50
# - Image-size: 120x120

# %%
# Define model architecture with num_epoch, batch_size, input image size
model_14 = model_architecture(50, 40, 120)
model_14.define_conv3d_architecture_1();
print('\n\n=========== Training the model ===========\n\n')
model_14.execute()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_10 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  batch_normalization_30 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  activation_2 (Activation)   (None, 30, 120, 120, 8)   0
#
#  conv3d_11 (Conv3D)          (None, 30, 120, 120, 16)  3472
#
#  batch_normalization_31 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 15, 60, 60, 16)   0
#  3D)
#
#  conv3d_12 (Conv3D)          (None, 15, 60, 60, 32)    4128
#
#  batch_normalization_32 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_13 (Conv3D)          (None, 7, 30, 30, 64)     16448
#
#  batch_normalization_33 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 3, 15, 15, 128)    65664
#
#  batch_normalization_34 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_6 (Flatten)         (None, 6272)              0
#
#  dense_14 (Dense)            (None, 1000)              6273000
#
#  dropout_12 (Dropout)        (None, 1000)              0
#
#  dense_15 (Dense)            (None, 500)               500500
#
#  dropout_13 (Dropout)        (None, 500)               0
#
#  dense_16 (Dense)            (None, 5)                 2505
#
# =================================================================
# Total params: 6,867,365
# Trainable params: 6,866,869
# Non-trainable params: 496
# _________________________________________________________________
# None
#
#
# =========== Training the model ===========
#
#
# Source path =  /home/datasets/Project_data/train ; batch size = 40
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 6.8580 - categorical_accuracy: 0.3394Source path =  /home/datasets/Project_data/val ; batch size = 40
#
# Epoch 00001: val_loss did not improve from 0.44253
# 17/17 [==============================] - 78s 5s/step - loss: 6.8580 - categorical_accuracy: 0.3394 - val_loss: 1.5539 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/50
# 17/17 [==============================] - ETA: 0s - loss: 2.2144 - categorical_accuracy: 0.4527
# Epoch 00002: val_loss did not improve from 0.44253
# 17/17 [==============================] - 47s 3s/step - loss: 2.2144 - categorical_accuracy: 0.4527 - val_loss: 3.7964 - val_categorical_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/50
# 17/17 [==============================] - ETA: 0s - loss: 1.7138 - categorical_accuracy: 0.5259
# Epoch 00003: val_loss did not improve from 0.44253
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] - 43s 3s/step - loss: 1.7138 - categorical_accuracy: 0.5259 - val_loss: 9.1737 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 4/50
# 17/17 [==============================] - ETA: 0s - loss: 1.4085 - categorical_accuracy: 0.5789
# Epoch 00004: val_loss did not improve from 0.44253
# 17/17 [==============================] - 41s 3s/step - loss: 1.4085 - categorical_accuracy: 0.5789 - val_loss: 10.6305 - val_categorical_accuracy: 0.0667 - lr: 5.0000e-04
# Epoch 5/50
# 17/17 [==============================] - ETA: 0s - loss: 1.3114 - categorical_accuracy: 0.5176
# Epoch 00005: val_loss did not improve from 0.44253
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 [==============================] - 38s 2s/step - loss: 1.3114 - categorical_accuracy: 0.5176 - val_loss: 9.3394 - val_categorical_accuracy: 0.2167 - lr: 5.0000e-04
# Epoch 6/50
# 17/17 [==============================] - ETA: 0s - loss: 0.7222 - categorical_accuracy: 0.7266
# Epoch 00006: val_loss did not improve from 0.44253
# 17/17 [==============================] - 38s 2s/step - loss: 0.7222 - categorical_accuracy: 0.7266 - val_loss: 10.8102 - val_categorical_accuracy: 0.1667 - lr: 2.5000e-04
# Epoch 7/50
# 17/17 [==============================] - ETA: 0s - loss: 0.7340 - categorical_accuracy: 0.6990
# Epoch 00007: val_loss did not improve from 0.44253
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 [==============================] - 38s 2s/step - loss: 0.7340 - categorical_accuracy: 0.6990 - val_loss: 12.4378 - val_categorical_accuracy: 0.1333 - lr: 2.5000e-04
# Epoch 8/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5718 - categorical_accuracy: 0.7855
# Epoch 00008: val_loss did not improve from 0.44253
# 17/17 [==============================] - 36s 2s/step - loss: 0.5718 - categorical_accuracy: 0.7855 - val_loss: 10.5850 - val_categorical_accuracy: 0.1500 - lr: 1.2500e-04
# Epoch 9/50
# 17/17 [==============================] - ETA: 0s - loss: 0.6065 - categorical_accuracy: 0.7578
# Epoch 00009: val_loss did not improve from 0.44253
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 17/17 [==============================] - 38s 2s/step - loss: 0.6065 - categorical_accuracy: 0.7578 - val_loss: 10.3320 - val_categorical_accuracy: 0.1500 - lr: 1.2500e-04
# Epoch 10/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5248 - categorical_accuracy: 0.8062
# Epoch 00010: val_loss did not improve from 0.44253
# 17/17 [==============================] - 39s 2s/step - loss: 0.5248 - categorical_accuracy: 0.8062 - val_loss: 9.7373 - val_categorical_accuracy: 0.2167 - lr: 6.2500e-05
# Epoch 11/50
# 17/17 [==============================] - ETA: 0s - loss: 0.5162 - categorical_accuracy: 0.7924
# Epoch 00011: val_loss did not improve from 0.44253
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 17/17 [==============================] - 36s 2s/step - loss: 0.5162 - categorical_accuracy: 0.7924 - val_loss: 11.0330 - val_categorical_accuracy: 0.1500 - lr: 6.2500e-05
# Epoch 12/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4661 - categorical_accuracy: 0.8304
# Epoch 00012: val_loss did not improve from 0.44253
# 17/17 [==============================] - 36s 2s/step - loss: 0.4661 - categorical_accuracy: 0.8304 - val_loss: 10.3852 - val_categorical_accuracy: 0.1833 - lr: 3.1250e-05
# Epoch 13/50
# 17/17 [==============================] - ETA: 0s - loss: 0.4623 - categorical_accuracy: 0.8512
# Epoch 00013: val_loss did not improve from 0.44253
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 17/17